# %%
from __future__ import print_function
from __future__ import division

import matplotlib.pyplot as plt
import numpy as np
import math

from config import cfg
from net import DCGAN
import tensorflow as tf

# %% [markdown]
# ### Set parameters
# All the parameters can be found in `config.py`

# %%
cfg.beta1 = 0.
cfg.beta2 = 0.99
cfg.batch_size = 16
cfg.save_period = 1000
cfg.display_period = 100
cfg.n_iters = 20000
cfg.n_critic = 1
cfg.learning_rate = 0.001
cfg.norm_g = 'pixel_norm'
cfg.norm_d = None
cfg.weight_scale = True
cfg.drift_loss = True
cfg.loss_mode = 'wgan_gp'
cfg.use_tanh = True
cfg.save_images = True

# %% [markdown]
# ### Step-1 : Train at 8x8 resolution
# In the paper, they start with 4x4 resolution but it doesn't matter

# %%
cfg.resolution = 8
cfg.transition = False
cfg.load_model = None

model = DCGAN(cfg)
model.train()
# Out:
# Size of training set :  53080
# Size of validation set :  5898
# WARNING:tensorflow:From /home/aat414/deep_final_project/progressive_growing_of_GANs/net.py:29: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# After 100 iterations Discriminator loss : 0.05087   Generator loss : -1.92685
# After 200 iterations Discriminator loss : -1.19733   Generator loss : 1.41205
# After 300 iterations Discriminator loss : -1.28041   Generator loss : 1.49783
# After 400 iterations Discriminator loss : -1.26788   Generator loss : 1.45132
# After 500 iterations Discriminator loss : -1.26336   Generator loss : 1.42576
# After 600 iterations Discriminator loss : -1.28301   Generator loss : 1.44535
# After 700 iterations Discriminator loss : -0.69052   Generator loss : 1.10882
# After 800 iterations Discriminator loss : -0.74943   Generator loss : 0.98583
# After 900 iterations Discriminator loss : -0.75852   Generator loss : 0.91767
# After 1000 iterations Discriminator loss : -0.75580   Generator loss : 0.86911
# Saving model in D:\Data\pgan\models/8x8/model
# Loading model...
# INFO:tensorflow:Restoring parameters from D:\Data\pgan\models/8x8/model-1000
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[Node: input_producer/input_producer/input_producer_EnqueueMany = QueueEnqueueManyV2[Tcomponents=[DT_INT32], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](input_producer/input_producer, input_producer/input_producer/RandomShuffle)]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, truediv_2)]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, truediv_2)]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, truediv_2)]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, truediv_2)]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, truediv_2)]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, truediv_2)]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, truediv_2)]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, truediv_2)]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, truediv_2)]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, truediv_2)]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, truediv_2)]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, truediv_2)]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, truediv_2)]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, truediv_2)]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, truediv_2)]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, truediv_2)]]
# Exception in thread QueueRunnerThread-batch/fifo_queue-batch/fifo_queue_enqueue:
# Traceback (most recent call last):
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py", line 252, in _run
#     enqueue_callable()
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1259, in _single_operation_run
#     None)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py", line 516, in __exit__
#     c_api.TF_GetCode(self.status.status))
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, truediv_2)]]
#
# Exception in thread QueueRunnerThread-batch/fifo_queue-batch/fifo_queue_enqueue:
# Traceback (most recent call last):
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py", line 252, in _run
#     enqueue_callable()
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1259, in _single_operation_run
#     None)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py", line 516, in __exit__
#     c_api.TF_GetCode(self.status.status))
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, truediv_2)]]
#
# Exception in thread QueueRunnerThread-batch/fifo_queue-batch/fifo_queue_enqueue:
# Traceback (most recent call last):
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py", line 252, in _run
#     enqueue_callable()
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1259, in _single_operation_run
#     None)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py", line 516, in __exit__
#     c_api.TF_GetCode(self.status.status))
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, truediv_2)]]
#
# Exception in thread QueueRunnerThread-batch/fifo_queue-batch/fifo_queue_enqueue:
# Traceback (most recent call last):
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py", line 252, in _run
#     enqueue_callable()
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1259, in _single_operation_run
#     None)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py", line 516, in __exit__
#     c_api.TF_GetCode(self.status.status))
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, truediv_2)]]
#
# Exception in thread QueueRunnerThread-batch/fifo_queue-batch/fifo_queue_enqueue:
# Traceback (most recent call last):
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py", line 252, in _run
#     enqueue_callable()
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1259, in _single_operation_run
#     None)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py", line 516, in __exit__
#     c_api.TF_GetCode(self.status.status))
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, truediv_2)]]
#
# Exception in thread QueueRunnerThread-batch/fifo_queue-batch/fifo_queue_enqueue:
# Traceback (most recent call last):
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py", line 252, in _run
#     enqueue_callable()
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1259, in _single_operation_run
#     None)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py", line 516, in __exit__
#     c_api.TF_GetCode(self.status.status))
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, truediv_2)]]
#
# Exception in thread QueueRunnerThread-batch/fifo_queue-batch/fifo_queue_enqueue:
# Traceback (most recent call last):
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py", line 252, in _run
#     enqueue_callable()
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1259, in _single_operation_run
#     None)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py", line 516, in __exit__
#     c_api.TF_GetCode(self.status.status))
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, truediv_2)]]
#
# Exception in thread QueueRunnerThread-input_producer/input_producer-input_producer/input_producer/input_producer_EnqueueMany:
# Traceback (most recent call last):
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py", line 252, in _run
#     enqueue_callable()
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1259, in _single_operation_run
#     None)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py", line 516, in __exit__
#     c_api.TF_GetCode(self.status.status))
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[Node: input_producer/input_producer/input_producer_EnqueueMany = QueueEnqueueManyV2[Tcomponents=[DT_INT32], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](input_producer/input_producer, input_producer/input_producer/RandomShuffle)]]
#
# Exception in thread QueueRunnerThread-batch/fifo_queue-batch/fifo_queue_enqueue:
# Traceback (most recent call last):
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py", line 252, in _run
#     enqueue_callable()
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1259, in _single_operation_run
#     None)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py", line 516, in __exit__
#     c_api.TF_GetCode(self.status.status))
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, truediv_2)]]
#
# Exception in thread QueueRunnerThread-batch/fifo_queue-batch/fifo_queue_enqueue:
# Traceback (most recent call last):
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py", line 252, in _run
#     enqueue_callable()
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1259, in _single_operation_run
#     None)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py", line 516, in __exit__
#     c_api.TF_GetCode(self.status.status))
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, truediv_2)]]
#
# Exception in thread QueueRunnerThread-batch/fifo_queue-batch/fifo_queue_enqueue:
# Traceback (most recent call last):
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py", line 252, in _run
#     enqueue_callable()
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1259, in _single_operation_run
#     None)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py", line 516, in __exit__
#     c_api.TF_GetCode(self.status.status))
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, truediv_2)]]
#
# Exception in thread QueueRunnerThread-batch/fifo_queue-batch/fifo_queue_enqueue:
# Traceback (most recent call last):
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py", line 252, in _run
#     enqueue_callable()
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1259, in _single_operation_run
#     None)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py", line 516, in __exit__
#     c_api.TF_GetCode(self.status.status))
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, truediv_2)]]
#
# Exception in thread QueueRunnerThread-batch/fifo_queue-batch/fifo_queue_enqueue:
# Traceback (most recent call last):
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py", line 252, in _run
#     enqueue_callable()
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1259, in _single_operation_run
#     None)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py", line 516, in __exit__
#     c_api.TF_GetCode(self.status.status))
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, truediv_2)]]
#
# Exception in thread QueueRunnerThread-batch/fifo_queue-batch/fifo_queue_enqueue:
# Traceback (most recent call last):
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py", line 252, in _run
#     enqueue_callable()
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1259, in _single_operation_run
#     None)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py", line 516, in __exit__
#     c_api.TF_GetCode(self.status.status))
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, truediv_2)]]
#
# Exception in thread QueueRunnerThread-batch/fifo_queue-batch/fifo_queue_enqueue:
# Traceback (most recent call last):
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py", line 252, in _run
#     enqueue_callable()
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1259, in _single_operation_run
#     None)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py", line 516, in __exit__
#     c_api.TF_GetCode(self.status.status))
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, truediv_2)]]
#
# Exception in thread QueueRunnerThread-batch/fifo_queue-batch/fifo_queue_enqueue:
# Traceback (most recent call last):
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py", line 252, in _run
#     enqueue_callable()
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1259, in _single_operation_run
#     None)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py", line 516, in __exit__
#     c_api.TF_GetCode(self.status.status))
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, truediv_2)]]
#
# Exception in thread QueueRunnerThread-batch/fifo_queue-batch/fifo_queue_enqueue:
# Traceback (most recent call last):
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py", line 252, in _run
#     enqueue_callable()
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1259, in _single_operation_run
#     None)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py", line 516, in __exit__
#     c_api.TF_GetCode(self.status.status))
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[Node: batch/fifo_queue_enqueue = QueueEnqueueV2[Tcomponents=[DT_FLOAT], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](batch/fifo_queue, truediv_2)]]
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# ~/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1360     try:
# -> 1361       return fn(*args)
#    1362     except errors.OpError as e:
#
# ~/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1339           return tf_session.TF_Run(session, options, feed_dict, fetch_list,
# -> 1340                                    target_list, status, run_metadata)
#    1341
#
# ~/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     515             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 516             c_api.TF_GetCode(self.status.status))
#     517     # Delete the underlying status object from memory otherwise it stays alive
#
# NotFoundError: Unsuccessful TensorSliceReader constructor: Failed to find any matching files for D:\Data\pgan\models/8x8/model-1000
# 	 [[Node: save_1/RestoreV2 = RestoreV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, ..., DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_INT32], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_1/Const_0_0, save_1/RestoreV2/tensor_names, save_1/RestoreV2/shape_and_slices)]]
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-4-a1dfd0d7c5f3> in <module>()
#       4
#       5 model = DCGAN(cfg)
# ----> 6 model.train()
#
# ~/deep_final_project/progressive_growing_of_GANs/model.py in train(self)
#     215                     saver.save(sess, save_dir, global_step)
#     216                     if self.cfg.save_images:
# --> 217                         gen_images = self.generate_images(save_tag, alpha=alpha)
#     218                         plt.figure(figsize=(10, 10))
#     219                         grid = image_loader.grid_batch_images(gen_images)
#
# ~/deep_final_project/progressive_growing_of_GANs/model.py in generate_images(self, model, batch_z, alpha)
#     237
#     238         with tf.Session() as sess:
# --> 239             self.load(sess, saver, model)
#     240             gen_images = sess.run(gen, feed_dict=feed_dict)
#     241             gen_images = image_loader.postprocess_image(gen_images)
#
# ~/deep_final_project/progressive_growing_of_GANs/model.py in load(self, sess, saver, tag)
#     253             print("Error: No saved model found. Please train first.")
#     254             sys.exit(0)
# --> 255         saver.restore(sess, checkpoint.model_checkpoint_path)
#
# ~/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/training/saver.py in restore(self, sess, save_path)
#    1753     if context.in_graph_mode():
#    1754       sess.run(self.saver_def.restore_op_name,
# -> 1755                {self.saver_def.filename_tensor_name: save_path})
#    1756     else:
#    1757       self._build_eager(save_path, build_save=False, build_restore=True)
#
# ~/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1135     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1136       results = self._do_run(handle, final_targets, final_fetches,
# -> 1137                              feed_dict_tensor, options, run_metadata)
#    1138     else:
#    1139       results = []
#
# ~/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1353     if handle is None:
#    1354       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1355                            options, run_metadata)
#    1356     else:
#    1357       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1372         except KeyError:
#    1373           pass
# -> 1374       raise type(e)(node_def, op, message)
#    1375
#    1376   def _extend_graph(self):
#
# NotFoundError: Unsuccessful TensorSliceReader constructor: Failed to find any matching files for D:\Data\pgan\models/8x8/model-1000
# 	 [[Node: save_1/RestoreV2 = RestoreV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, ..., DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_INT32], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_1/Const_0_0, save_1/RestoreV2/tensor_names, save_1/RestoreV2/shape_and_slices)]]
#
# Caused by op 'save_1/RestoreV2', defined at:
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/traitlets-4.3.2-py3.6.egg/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 112, in start
#     self.asyncio_loop.run_forever()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/asyncio/base_events.py", line 421, in run_forever
#     self._run_once()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/asyncio/base_events.py", line 1426, in _run_once
#     handle._run()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/asyncio/events.py", line 127, in _run
#     self._callback(*self._args)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 102, in _handle_events
#     handler_func(fileobj, events)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/core/interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/core/interactiveshell.py", line 2856, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-4-a1dfd0d7c5f3>", line 6, in <module>
#     model.train()
#   File "/home/aat414/deep_final_project/progressive_growing_of_GANs/model.py", line 217, in train
#     gen_images = self.generate_images(save_tag, alpha=alpha)
#   File "/home/aat414/deep_final_project/progressive_growing_of_GANs/model.py", line 232, in generate_images
#     saver = tf.train.Saver()
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1293, in __init__
#     self.build()
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1302, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1339, in _build
#     build_save=build_save, build_restore=build_restore)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 796, in _build_internal
#     restore_sequentially, reshape)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 449, in _AddRestoreOps
#     restore_sequentially)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 847, in bulk_restore
#     return io_ops.restore_v2(filename_tensor, names, slices, dtypes)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/ops/gen_io_ops.py", line 1030, in restore_v2
#     shape_and_slices=shape_and_slices, dtypes=dtypes, name=name)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 3271, in create_op
#     op_def=op_def)
#   File "/home/aat414/pyenv/py3.6.3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1650, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# NotFoundError (see above for traceback): Unsuccessful TensorSliceReader constructor: Failed to find any matching files for D:\Data\pgan\models/8x8/model-1000
# 	 [[Node: save_1/RestoreV2 = RestoreV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, ..., DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_INT32], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_1/Const_0_0, save_1/RestoreV2/tensor_names, save_1/RestoreV2/shape_and_slices)]]

# %% [markdown]
# ### Step-2 : Transition from 8x8 to 16x16 resolution (fading)
# Note that this step will automatically load model from 8x8 resolution (`models/8x8`). So, you can leave `cfg.load_model = None`.

# %%
cfg.resolution = 16
cfg.transition = True
cfg.load_model = None

model = DCGAN(cfg)
model.train()

# %% [markdown]
# ### Step-3 : Train at  16x16 resolution
# Now, you must load model from previous step to continue. Model from previous step is saved in `models/16x16_transition`, so we set `cfg.load_model = '16x16_transition`.

# %%
cfg.resolution = 16
cfg.transition = False
cfg.load_model = '16x16_transition'

model = DCGAN(cfg)
model.train()

# %% [markdown]
# ### Step-4 : Transition from 16x16 to 32x32 resolution (fading)
# Again, this step will automatically load model from `models/16x16`.

# %%
cfg.resolution = 32
cfg.transition = True
cfg.load_model = None

model = DCGAN(cfg)
model.train()

# %% [markdown]
# ### Step-5 : Train at  32x32 resolution
# Now, we load model from previous step saved in `models/32x32_transition`

# %%
cfg.resolution = 32
cfg.transition = False
cfg.load_model = '32x32_transition'

model = DCGAN(cfg)
model.train()

# %% [markdown]
# Hopefully, you get the idea now. So you can continue this process to higher resolutions.
